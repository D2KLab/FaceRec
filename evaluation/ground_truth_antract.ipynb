# %%
import os
import sys
sys.path.insert(0, os.path.abspath('../src'))

import copy
import re
from tqdm.notebook import tqdm

import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON
from frame_collector import FrameCollector
from src.connectors import antract_connector as antract
from src.utils.media_fragment import convert_to_seconds_npt
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0429 13:58:30.799485 4543577536 deprecation.py:506] From /usr/local/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
ENDPOINT = "https://okapi.ina.fr/antract/api/saphir/sparql_search"
sparql = SPARQLWrapper(ENDPOINT)
sparql.setReturnFormat(JSON)

# %%
with open('celebrities.txt', encoding='utf-8') as file:
    celebrities_names = [l.strip() for l in file.readlines()]
celebrities_names
# Out:
# ['Ben Bella, Ahmed',
#  'Gaulle, Charles de',
#  'Eisenhower, Dwight David',
#  "Elizabeth d'Angleterre",
#  'Mitterrand, François',
#  'Bidault, Georges',
#  'Pompidou, Georges',
#  'Mollet, Guy',
#  'Adenauer, Konrad',
#  'Khrouchtchev, Nikita',
#  'Mendès France, Pierre',
#  'Molotov, Viatcheslav',
#  'Auriol, Vincent']

# %%
with open('person_by_name.rq') as file:
    query = file.read()

# %%
def get_celebrity_uri(name):
    q = query.replace('?label', '"%s"' % name)
    sparql.setQuery(q)
    results = sparql.query().convert()["results"]["bindings"]
    return results[0]['person']['value']

celebrities_uri = [get_celebrity_uri(c) for c in celebrities_names]

for uri, name in zip(celebrities_uri, celebrities_names):
    print('%s\t%s'%(uri,name))
# Out:
# http://www.ina.fr/thesaurus/pp/concept_10202345	Ben Bella, Ahmed
# http://www.ina.fr/thesaurus/pp/concept_10075863	Gaulle, Charles de
# http://www.ina.fr/thesaurus/pp/concept_10128605	Eisenhower, Dwight David
# http://www.ina.fr/thesaurus/pp/concept_330024	Elizabeth d'Angleterre
# http://www.ina.fr/thesaurus/pp/concept_10080266	Mitterrand, François
# http://www.ina.fr/thesaurus/pp/concept_10217774	Bidault, Georges
# http://www.ina.fr/thesaurus/pp/concept_10074163	Pompidou, Georges
# http://www.ina.fr/thesaurus/pp/concept_10176011	Mollet, Guy
# http://www.ina.fr/thesaurus/pp/concept_10147429	Adenauer, Konrad
# http://www.ina.fr/thesaurus/pp/concept_10130157	Khrouchtchev, Nikita
# http://www.ina.fr/thesaurus/pp/concept_10200837	Mendès France, Pierre
# http://www.ina.fr/thesaurus/pp/concept_10160074	Molotov, Viatcheslav
# http://www.ina.fr/thesaurus/pp/concept_10172212	Auriol, Vincent

# %%
with open('segment_by_person.rq') as file:
    query = file.read()

# %%
def pad_spaces(text):
    pad = 25 - len(text)
    return text + ''.join([' ' for _ in range(0,pad)])
    
def get_segments(person, name):
    q = query.replace('?person', '<%s>' % person)
    sparql.setQuery(q)
    results = sparql.query().convert()["results"]["bindings"]
    for r in results:
        for p in r:
            value = r[p]['value']
            if p in ['start', 'end']:
                value = convert_to_seconds_npt(re.sub(r"T(\d{2}:\d{2}:\d{2}).+", "\g<1>", value))
            if p == 'prop':
                value = re.split(r"[/#]", value)[-1]
            r[p] = value
        r['person'] = name
        r['person_uri'] = person
    print('- %s\t%s'%(pad_spaces(name), len(results)))
    
    
    return pd.DataFrame.from_dict([r for r in results if r['start'] < r['end']])

print('Num. results per person:')
df = pd.concat([get_segments(uri, name) 
                     for uri, name in tqdm(zip(celebrities_uri, celebrities_names), total=len(celebrities_names))],
               ignore_index=True)
df.head()
# Out:
# Num. results per person:
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))
# - Ben Bella, Ahmed         	17
# - Gaulle, Charles de       	406
# - Eisenhower, Dwight David 	88
# - Elizabeth d'Angleterre   	42
# - Mitterrand, François     	24
# - Bidault, Georges         	110
# - Pompidou, Georges        	113
# - Mollet, Guy              	65
# - Adenauer, Konrad         	65
# - Khrouchtchev, Nikita     	65
# - Mendès France, Pierre    	42
# - Molotov, Viatcheslav     	38
# - Auriol, Vincent          	200
#                                  media  \
# 0  http://www.ina.fr/media/AFE86003838
# 1  http://www.ina.fr/media/AFE86003847
# 2  http://www.ina.fr/media/AFE86003893
# 3  http://www.ina.fr/media/AFE86004111
# 4  http://www.ina.fr/media/AFE86003905
#
#                                                title  start    end  \
# 0             A Tlemcen, Ferhat Abbas chez Ben Bella  232.0  288.0
# 1                           Les élections en Algérie  138.0  212.0
# 2  La conférence de l' Organisation de l'unité af...   14.0   43.0
# 3  L'ami de Fidel Castro, un homme dans la révolu...  239.0  330.0
# 4  L'accord Algero - Marocain... mais les combats...  231.0  311.0
#
#                          url            person  \
# 0  /Media/AF/AFE86003838.mp4  Ben Bella, Ahmed
# 1  /Media/AF/AFE86003847.mp4  Ben Bella, Ahmed
# 2  /Media/AF/AFE86003893.mp4  Ben Bella, Ahmed
# 3  /Media/AF/AFE86004111.mp4  Ben Bella, Ahmed
# 4  /Media/AF/AFE86003905.mp4  Ben Bella, Ahmed
#
#                                         person_uri
# 0  http://www.ina.fr/thesaurus/pp/concept_10202345
# 1  http://www.ina.fr/thesaurus/pp/concept_10202345
# 2  http://www.ina.fr/thesaurus/pp/concept_10202345
# 3  http://www.ina.fr/thesaurus/pp/concept_10202345
# 4  http://www.ina.fr/thesaurus/pp/concept_10202345

# %%
len(df)
# Out:
# 1224

# %%
with open('shots_by_segment.rq') as file:
    query = file.read()
    
def get_shots(row):
    q = query.replace('?media', '<%s>' % row['media'])
    sparql.setQuery(q)
    results = sparql.query().convert()["results"]["bindings"]
    for r in results:
        for p in r:
            value = r[p]['value']
            if p in ['start', 'end']:
                value = convert_to_seconds_npt(re.sub(r"T(\d{2}:\d{2}:\d{2}).+", "\g<1>", value))
            if p == 'prop':
                value = re.split(r"[/#]", value)[-1]
            r[p] = value
        r['media'] = row['media']
        r['person'] = row['person']
        r['url'] = row['url']
        start = row['start']
        end = row['end']
    results = [r for r in results 
               if(r['start'] >= start and r['end'] <= end and r['start'] != r['end'])]
    if len(results) == 0:
        print('Empty results for %s (%s - %s, %s)'%( row['media'], row['person'], start, end))
    return pd.DataFrame.from_dict(results)

# %%
shots = pd.concat([get_shots(row)
                   for idx, row in tqdm(df.iterrows(),total=len(df))], ignore_index=True)
shots.head()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1224.0), HTML(value='')))
#                                              layer  \
# 0  http://www.campus-AAR.fr/sceneLayer_AFE86003838
# 1  http://www.campus-AAR.fr/sceneLayer_AFE86003838
# 2  http://www.campus-AAR.fr/sceneLayer_AFE86003838
# 3  http://www.campus-AAR.fr/sceneLayer_AFE86003838
# 4  http://www.campus-AAR.fr/sceneLayer_AFE86003838
#
#                                              segment  start    end  \
# 0  http://www.campus-AAR.fr/sceneSegment_AFE86003...  232.0  235.0
# 1  http://www.campus-AAR.fr/sceneSegment_AFE86003...  235.0  239.0
# 2  http://www.campus-AAR.fr/sceneSegment_AFE86003...  239.0  244.0
# 3  http://www.campus-AAR.fr/sceneSegment_AFE86003...  244.0  246.0
# 4  http://www.campus-AAR.fr/sceneSegment_AFE86003...  246.0  250.0
#
#                                  media            person  \
# 0  http://www.ina.fr/media/AFE86003838  Ben Bella, Ahmed
# 1  http://www.ina.fr/media/AFE86003838  Ben Bella, Ahmed
# 2  http://www.ina.fr/media/AFE86003838  Ben Bella, Ahmed
# 3  http://www.ina.fr/media/AFE86003838  Ben Bella, Ahmed
# 4  http://www.ina.fr/media/AFE86003838  Ben Bella, Ahmed
#
#                          url
# 0  /Media/AF/AFE86003838.mp4
# 1  /Media/AF/AFE86003838.mp4
# 2  /Media/AF/AFE86003838.mp4
# 3  /Media/AF/AFE86003838.mp4
# 4  /Media/AF/AFE86003838.mp4

# %%
len(shots)
# Out:
# 48

# %%
# from importlib import reload
# reload(frame_collector)
# FrameCollector = frame_collector.FrameCollector

# %%
old_loc = ''
fc = None

shots.sort_values(by='media', ascending=False)

table = shots

def ex_frame(row):
    loc = antract.apply_auth('https://okapi.ina.fr/antract' + row['url'])
    if loc != old_loc:
        fc = FrameCollector(loc,'antract')
    
    start = row['start']
    end = row['end']
    center = int((start + end) / 2)
    
    return fc.run(fragment=[center])

filenames = [ex_frame(row) for idx, row in tqdm(table.iterrows(), total=len(table))]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=48.0), HTML(value='')))

# %%
shots['frame_file'] = filenames
shots.to_csv(r'shots.csv', index = False)

# %%
# Out:
#                                               layer  \
# 0   http://www.campus-AAR.fr/sceneLayer_AFE86003838
# 1   http://www.campus-AAR.fr/sceneLayer_AFE86003838
# 2   http://www.campus-AAR.fr/sceneLayer_AFE86003838
# 3   http://www.campus-AAR.fr/sceneLayer_AFE86003838
# 4   http://www.campus-AAR.fr/sceneLayer_AFE86003838
# 5   http://www.campus-AAR.fr/sceneLayer_AFE86003838
# 6   http://www.campus-AAR.fr/sceneLayer_AFE86003838
# 7   http://www.campus-AAR.fr/sceneLayer_AFE86003838
# 8   http://www.campus-AAR.fr/sceneLayer_AFE86003838
# 9   http://www.campus-AAR.fr/sceneLayer_AFE86003838
# 10  http://www.campus-AAR.fr/sceneLayer_AFE86003838
# 11  http://www.campus-AAR.fr/sceneLayer_AFE86003838
# 12  http://www.campus-AAR.fr/sceneLayer_AFE86003838
# 13  http://www.campus-AAR.fr/sceneLayer_AFE86003838
# 14  http://www.campus-AAR.fr/sceneLayer_AFE86003838
# 15  http://www.campus-AAR.fr/sceneLayer_AFE86003838
# 16  http://www.campus-AAR.fr/sceneLayer_AFE86003838
# 17  http://www.campus-AAR.fr/sceneLayer_AFE86003838
# 18  http://www.campus-AAR.fr/sceneLayer_AFE86003838
# 19  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 20  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 21  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 22  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 23  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 24  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 25  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 26  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 27  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 28  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 29  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 30  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 31  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 32  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 33  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 34  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 35  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 36  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 37  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 38  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 39  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 40  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 41  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 42  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 43  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 44  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 45  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 46  http://www.campus-AAR.fr/sceneLayer_AFE86003847
# 47  http://www.campus-AAR.fr/sceneLayer_AFE86003847
#
#                                               segment  start    end  \
# 0   http://www.campus-AAR.fr/sceneSegment_AFE86003...  232.0  235.0
# 1   http://www.campus-AAR.fr/sceneSegment_AFE86003...  235.0  239.0
# 2   http://www.campus-AAR.fr/sceneSegment_AFE86003...  239.0  244.0
# 3   http://www.campus-AAR.fr/sceneSegment_AFE86003...  244.0  246.0
# 4   http://www.campus-AAR.fr/sceneSegment_AFE86003...  246.0  250.0
# 5   http://www.campus-AAR.fr/sceneSegment_AFE86003...  250.0  254.0
# 6   http://www.campus-AAR.fr/sceneSegment_AFE86003...  254.0  256.0
# 7   http://www.campus-AAR.fr/sceneSegment_AFE86003...  256.0  259.0
# 8   http://www.campus-AAR.fr/sceneSegment_AFE86003...  259.0  261.0
# 9   http://www.campus-AAR.fr/sceneSegment_AFE86003...  261.0  263.0
# 10  http://www.campus-AAR.fr/sceneSegment_AFE86003...  263.0  266.0
# 11  http://www.campus-AAR.fr/sceneSegment_AFE86003...  266.0  269.0
# 12  http://www.campus-AAR.fr/sceneSegment_AFE86003...  269.0  271.0
# 13  http://www.campus-AAR.fr/sceneSegment_AFE86003...  271.0  274.0
# 14  http://www.campus-AAR.fr/sceneSegment_AFE86003...  274.0  276.0
# 15  http://www.campus-AAR.fr/sceneSegment_AFE86003...  276.0  278.0
# 16  http://www.campus-AAR.fr/sceneSegment_AFE86003...  278.0  281.0
# 17  http://www.campus-AAR.fr/sceneSegment_AFE86003...  281.0  284.0
# 18  http://www.campus-AAR.fr/sceneSegment_AFE86003...  284.0  287.0
# 19  http://www.campus-AAR.fr/sceneSegment_AFE86003...  138.0  141.0
# 20  http://www.campus-AAR.fr/sceneSegment_AFE86003...  141.0  142.0
# 21  http://www.campus-AAR.fr/sceneSegment_AFE86003...  142.0  145.0
# 22  http://www.campus-AAR.fr/sceneSegment_AFE86003...  145.0  147.0
# 23  http://www.campus-AAR.fr/sceneSegment_AFE86003...  147.0  149.0
# 24  http://www.campus-AAR.fr/sceneSegment_AFE86003...  149.0  151.0
# 25  http://www.campus-AAR.fr/sceneSegment_AFE86003...  151.0  152.0
# 26  http://www.campus-AAR.fr/sceneSegment_AFE86003...  152.0  153.0
# 27  http://www.campus-AAR.fr/sceneSegment_AFE86003...  153.0  154.0
# 28  http://www.campus-AAR.fr/sceneSegment_AFE86003...  154.0  162.0
# 29  http://www.campus-AAR.fr/sceneSegment_AFE86003...  162.0  164.0
# 30  http://www.campus-AAR.fr/sceneSegment_AFE86003...  164.0  167.0
# 31  http://www.campus-AAR.fr/sceneSegment_AFE86003...  167.0  170.0
# 32  http://www.campus-AAR.fr/sceneSegment_AFE86003...  170.0  172.0
# 33  http://www.campus-AAR.fr/sceneSegment_AFE86003...  172.0  174.0
# 34  http://www.campus-AAR.fr/sceneSegment_AFE86003...  174.0  176.0
# 35  http://www.campus-AAR.fr/sceneSegment_AFE86003...  176.0  179.0
# 36  http://www.campus-AAR.fr/sceneSegment_AFE86003...  179.0  181.0
# 37  http://www.campus-AAR.fr/sceneSegment_AFE86003...  181.0  184.0
# 38  http://www.campus-AAR.fr/sceneSegment_AFE86003...  184.0  185.0
# 39  http://www.campus-AAR.fr/sceneSegment_AFE86003...  185.0  188.0
# 40  http://www.campus-AAR.fr/sceneSegment_AFE86003...  188.0  191.0
# 41  http://www.campus-AAR.fr/sceneSegment_AFE86003...  191.0  196.0
# 42  http://www.campus-AAR.fr/sceneSegment_AFE86003...  196.0  200.0
# 43  http://www.campus-AAR.fr/sceneSegment_AFE86003...  200.0  202.0
# 44  http://www.campus-AAR.fr/sceneSegment_AFE86003...  202.0  204.0
# 45  http://www.campus-AAR.fr/sceneSegment_AFE86003...  204.0  208.0
# 46  http://www.campus-AAR.fr/sceneSegment_AFE86003...  208.0  209.0
# 47  http://www.campus-AAR.fr/sceneSegment_AFE86003...  209.0  212.0
#
#                                   media            person  \
# 0   http://www.ina.fr/media/AFE86003838  Ben Bella, Ahmed
# 1   http://www.ina.fr/media/AFE86003838  Ben Bella, Ahmed
# 2   http://www.ina.fr/media/AFE86003838  Ben Bella, Ahmed
# 3   http://www.ina.fr/media/AFE86003838  Ben Bella, Ahmed
# 4   http://www.ina.fr/media/AFE86003838  Ben Bella, Ahmed
# 5   http://www.ina.fr/media/AFE86003838  Ben Bella, Ahmed
# 6   http://www.ina.fr/media/AFE86003838  Ben Bella, Ahmed
# 7   http://www.ina.fr/media/AFE86003838  Ben Bella, Ahmed
# 8   http://www.ina.fr/media/AFE86003838  Ben Bella, Ahmed
# 9   http://www.ina.fr/media/AFE86003838  Ben Bella, Ahmed
# 10  http://www.ina.fr/media/AFE86003838  Ben Bella, Ahmed
# 11  http://www.ina.fr/media/AFE86003838  Ben Bella, Ahmed
# 12  http://www.ina.fr/media/AFE86003838  Ben Bella, Ahmed
# 13  http://www.ina.fr/media/AFE86003838  Ben Bella, Ahmed
# 14  http://www.ina.fr/media/AFE86003838  Ben Bella, Ahmed
# 15  http://www.ina.fr/media/AFE86003838  Ben Bella, Ahmed
# 16  http://www.ina.fr/media/AFE86003838  Ben Bella, Ahmed
# 17  http://www.ina.fr/media/AFE86003838  Ben Bella, Ahmed
# 18  http://www.ina.fr/media/AFE86003838  Ben Bella, Ahmed
# 19  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 20  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 21  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 22  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 23  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 24  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 25  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 26  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 27  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 28  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 29  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 30  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 31  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 32  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 33  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 34  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 35  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 36  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 37  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 38  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 39  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 40  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 41  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 42  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 43  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 44  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 45  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 46  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
# 47  http://www.ina.fr/media/AFE86003847  Ben Bella, Ahmed
#
#                           url                                 frame_file
# 0   /Media/AF/AFE86003838.mp4                                          0
# 1   /Media/AF/AFE86003838.mp4  ./frames/antract/AFE86003838.mp4_5925.jpg
# 2   /Media/AF/AFE86003838.mp4  ./frames/antract/AFE86003838.mp4_6025.jpg
# 3   /Media/AF/AFE86003838.mp4  ./frames/antract/AFE86003838.mp4_6125.jpg
# 4   /Media/AF/AFE86003838.mp4  ./frames/antract/AFE86003838.mp4_6200.jpg
# 5   /Media/AF/AFE86003838.mp4  ./frames/antract/AFE86003838.mp4_6300.jpg
# 6   /Media/AF/AFE86003838.mp4                                          0
# 7   /Media/AF/AFE86003838.mp4                                          0
# 8   /Media/AF/AFE86003838.mp4  ./frames/antract/AFE86003838.mp4_6500.jpg
# 9   /Media/AF/AFE86003838.mp4                                          0
# 10  /Media/AF/AFE86003838.mp4                                          0
# 11  /Media/AF/AFE86003838.mp4  ./frames/antract/AFE86003838.mp4_6675.jpg
# 12  /Media/AF/AFE86003838.mp4  ./frames/antract/AFE86003838.mp4_6750.jpg
# 13  /Media/AF/AFE86003838.mp4  ./frames/antract/AFE86003838.mp4_6800.jpg
# 14  /Media/AF/AFE86003838.mp4  ./frames/antract/AFE86003838.mp4_6875.jpg
# 15  /Media/AF/AFE86003838.mp4  ./frames/antract/AFE86003838.mp4_6925.jpg
# 16  /Media/AF/AFE86003838.mp4  ./frames/antract/AFE86003838.mp4_6975.jpg
# 17  /Media/AF/AFE86003838.mp4                                          0
# 18  /Media/AF/AFE86003838.mp4  ./frames/antract/AFE86003838.mp4_7125.jpg
# 19  /Media/AF/AFE86003847.mp4                                          0
# 20  /Media/AF/AFE86003847.mp4                                          0
# 21  /Media/AF/AFE86003847.mp4                                          0
# 22  /Media/AF/AFE86003847.mp4                                          0
# 23  /Media/AF/AFE86003847.mp4                                          0
# 24  /Media/AF/AFE86003847.mp4  ./frames/antract/AFE86003847.mp4_3750.jpg
# 25  /Media/AF/AFE86003847.mp4  ./frames/antract/AFE86003847.mp4_3775.jpg
# 26  /Media/AF/AFE86003847.mp4  ./frames/antract/AFE86003847.mp4_3800.jpg
# 27  /Media/AF/AFE86003847.mp4  ./frames/antract/AFE86003847.mp4_3825.jpg
# 28  /Media/AF/AFE86003847.mp4                                          0
# 29  /Media/AF/AFE86003847.mp4                                          0
# 30  /Media/AF/AFE86003847.mp4  ./frames/antract/AFE86003847.mp4_4125.jpg
# 31  /Media/AF/AFE86003847.mp4  ./frames/antract/AFE86003847.mp4_4200.jpg
# 32  /Media/AF/AFE86003847.mp4                                          0
# 33  /Media/AF/AFE86003847.mp4  ./frames/antract/AFE86003847.mp4_4325.jpg
# 34  /Media/AF/AFE86003847.mp4  ./frames/antract/AFE86003847.mp4_4375.jpg
# 35  /Media/AF/AFE86003847.mp4                                          0
# 36  /Media/AF/AFE86003847.mp4                                          0
# 37  /Media/AF/AFE86003847.mp4  ./frames/antract/AFE86003847.mp4_4550.jpg
# 38  /Media/AF/AFE86003847.mp4  ./frames/antract/AFE86003847.mp4_4600.jpg
# 39  /Media/AF/AFE86003847.mp4  ./frames/antract/AFE86003847.mp4_4650.jpg
# 40  /Media/AF/AFE86003847.mp4                                          0
# 41  /Media/AF/AFE86003847.mp4                                          0
# 42  /Media/AF/AFE86003847.mp4  ./frames/antract/AFE86003847.mp4_4950.jpg
# 43  /Media/AF/AFE86003847.mp4                                          0
# 44  /Media/AF/AFE86003847.mp4                                          0
# 45  /Media/AF/AFE86003847.mp4  ./frames/antract/AFE86003847.mp4_5150.jpg
# 46  /Media/AF/AFE86003847.mp4  ./frames/antract/AFE86003847.mp4_5200.jpg
# 47  /Media/AF/AFE86003847.mp4  ./frames/antract/AFE86003847.mp4_5250.jpg
